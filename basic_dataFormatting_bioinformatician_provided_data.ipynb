# %%
import os
import shutil
import pandas as pd
import re

# %%
dfs = []
for file_name in os.listdir('data/finalized'):
    file_path = os.path.join("data/finalized", file_name)
    dfs.append(pd.read_csv(file_path))

# %%
result_df = dfs[3]
result_df.head(5)
# Out:
#         col        md0        md1       md2        md3        md4        md5  \
# 0  Outcomes   1.000000   1.000000   1.00000   1.000000   1.000000   1.000000
# 1    TSPAN6  84.865100  76.867400  83.67390  59.774000  63.825400  61.571200
# 2      TNMD   0.395107   0.610888   1.35942   0.787316   0.218991   0.482109
# 3      DPM1  45.236200  41.082500  40.71090  48.908700  48.253600  46.886100
# 4     SCYL3   5.072610   3.924850   5.00336   6.014880   4.950510   5.380790
#
#         md6       md7       md8       md9      md10      md11
# 0   1.00000   1.00000   1.00000   1.00000   1.00000   1.00000
# 1  74.74600  84.07390  84.91110  77.98930  74.67730  66.80190
# 2   2.98019   3.85128   4.19281   1.81964   1.48654   1.87628
# 3  42.12880  42.51110  44.16380  38.34620  41.92180  40.12510
# 4   4.86405   4.61122   6.35072   5.93592   6.06586   3.68730

# %%
dfs.pop(-1)
# Out:
#             col        md0        md1        md2        md3        md4  \
# 0      Outcomes   1.000000   1.000000   1.000000   1.000000   1.000000
# 1        TSPAN6  84.865100  76.867400  83.673900  59.774000  63.825400
# 2          TNMD   0.395107   0.610888   1.359420   0.787316   0.218991
# 3          DPM1  45.236200  41.082500  40.710900  48.908700  48.253600
# 4         SCYL3   5.072610   3.924850   5.003360   6.014880   4.950510
# ...         ...        ...        ...        ...        ...        ...
# 57780     PGAM1  73.615000  79.976500  78.118400  77.236633  77.236633
# 57781      FBP1   1.970380   1.847190   2.239970   1.386570   1.022450
# 57782      PCK1   0.886300   0.655173   0.745203   6.689000   6.879940
# 57783      FBP2   1.393150   1.248330   1.455760   1.104290   1.174290
# 57784     PGAM2   0.000447   0.381709   0.638181   0.073682   0.000000
#
#              md5        md6        md7        md8        md9      md10  \
# ...

# %%
len(dfs)
# Out:
# 3

# %%
for df in dfs:
    result_df = pd.merge(result_df, df, on='col', how='left')

# %%
result_df.head(5)
# Out:
#         col        md0        md1       md2        md3        md4        md5  \
# 0  Outcomes   1.000000   1.000000   1.00000   1.000000   1.000000   1.000000
# 1    TSPAN6  84.865100  76.867400  83.67390  59.774000  63.825400  61.571200
# 2      TNMD   0.395107   0.610888   1.35942   0.787316   0.218991   0.482109
# 3      DPM1  45.236200  41.082500  40.71090  48.908700  48.253600  46.886100
# 4     SCYL3   5.072610   3.924850   5.00336   6.014880   4.950510   5.380790
#
#         md6       md7       md8  ...       vnd_0  vnd_1       vnd_2  \
# 0   1.00000   1.00000   1.00000  ...    0.000000    0.0    1.000000
# 1  74.74600  84.07390  84.91110  ...  486.872564  459.0  433.958026
# 2   2.98019   3.85128   4.19281  ...         NaN    NaN         NaN
# 3  42.12880  42.51110  44.16380  ...  980.686284  919.0  931.644154
# 4   4.86405   4.61122   6.35072  ...  122.957633  172.0  130.490875
#
#         vnd_3         cm1         cm2         cm3         cm4         cm5  \
# ...

# %%
result_df.to_csv("data/finalized/combined_all.csv", index=False)

# %%
# Out:
#                           col   values
# 0                     Outcome        1
# 1                        A1BG       20
# 2                    A1BG-AS1       88
# 3                        A1CF        0
# 4                         A2M       31
# ...                       ...      ...
# 27457            __no_feature  3765480
# 27458             __ambiguous   265224
# 27459         __too_low_aQual        0
# 27460           __not_aligned        0
# 27461  __alignment_not_unique  7541225
#
# [27462 rows x 2 columns]
