# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
data = pd.read_csv("data/processed_biomarkers_features.csv")

# %%
print("data.shape:", data.shape)
# Out:
# data.shape: (41, 15)

# %%
profile = ProfileReport(data, title="Glioblastoma multiforme profile")

# %%
profile.to_file("Glioblastoma multiforme EDA report_by_Sajjad Ali Khan.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
