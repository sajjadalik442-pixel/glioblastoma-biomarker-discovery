# %%
import pandas as pd

# %%
#bio_markers = ['FOS', 'MYC', 'IL6', 'PTGS2', 'TNF', 'CD4', 'MAPK3', 'CXCR4', 'IL2', 'EGF', 'IL1A', 'CRP', 'IL1B', 'ALB', 'Outcomes']
#, 'CXCL8'
#markers_features = ['EGF', 'NOTCH3', 'ANK1', 'ESR1', 'ATP6V1B1', 'NTRK1', 'MYOZ1', 'JAG1', 'NGFR', 'NOTCH2', 'CD163', 'FOXM1', 'FN1', 'CXCL8', 'MYC', 
#                    'CXCL1', 'TIMP1', 'CCL2', 'IL10', 'ANXA5', 'Outcomes']

markers_features = ['AKT1', 'EGFR', 'TP53', 'CDKN2A', 'IDH1', 'MGMT', 'PTEN', 'TERT', 'CDKN2B', 'IDH2', 'PROM1', 'CD68', 'PRR15', 'SLC25A41', 'Outcome']

# %%
data = pd.read_csv('data/finalized_data.csv')
data.shape
# Out:
# (41, 15276)

# %%
#data = data[bio_markers]
data = data[markers_features]
data.shape
# Out:
# (41, 15)

# %%
data
# Out:
#     AKT1   EGFR  TP53  CDKN2A  IDH1  MGMT   PTEN  TERT  CDKN2B   IDH2  PROM1  \
# 0      6     44    12       0    14     1     48     0       0     36      0
# 1     10     11    13       0    10     2     53     0       0     12      0
# 2      6     11     7       0     1     7     33     0       2     26      1
# 3      8     20     6       2    16     9     56     0       0     18      1
# 4      5     42    17       0    13     0     34     0       0      5      0
# 5      9     21    13       0    13     1     33     0       0      1      0
# 6     19     10     7       1    26     4     85     0       0     60      2
# 7      7     14     9       0    14    10     79     0       0     52      1
# 8      7     26    23       0    19     8     54     0       1     30      2
# 9      2      8    15       0     6     2     16     0       0      6      0
# 10     2      3     6       0     3     1      3     0       0      4      0
# ...

# %%
data.to_csv('data/processed_biomarkers_features.csv', index=False)
